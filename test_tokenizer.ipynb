# %%
from tokenization_enc_dec import EncDecTokenizer

# %%
tokenizer = EncDecTokenizer('./vocab.txt')

# %%
tokenizer.encode('你')
# Out:
# [34]

# %%
tokenizer.decode([8028, 34, 16, 34, 26152, 26104])
# Out:
# '我爱你，你<s_102><s_54>'

# %%
dir(tokenizer)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'convert_ids_to_tokens',
#  'convert_tokens_to_ids',
#  'decode',
#  'decoder',
#  'encode',
#  'encoder',
#  'eod_id',
#  'eod_token',
#  'get_sentinel_id',
#  'get_sentinel_num',
#  'max_len',
#  'pad_id',
#  'pad_token',
#  'sentinel_list',
#  'tokenize',
#  'translator',
#  'vocab_size',
#  'wordpiece_tokenizer']

# %%
tokenizer.get_sentinel_id(0)
# Out:
# 26050

# %%
tokenizer.get_sentinel_num()
# Out:
# 190

# %%
tokenizer.eod_id
# Out:
# 7

# %%
tokenizer.pad_id
# Out:
# 5

# %%
for i in range(10):
    t = tokenizer.convert_ids_to_tokens([i])
    print(i, t)
# Out:
# 0 ['<unk>']
# 1 ['<s>']
# 2 ['</s>']
# 3 ['▃']
# 4 ['<sep>']
# 5 ['<pad>']
# 6 ['<mask>']
# 7 ['<eod>']
# 8 ['▁']
# 9 [',']

# %%
tokens = [tokenizer.convert_ids_to_tokens([i])[0] for i in range(tokenizer.vocab_size)]

# %%
tokens_set = set(tokens)

# %%
bert_vocab = open('bert/vocab.txt').read().split('\n')

# %%
for x in bert_vocab:
    if len(x) == 1:
        if x in tokens_set:
            pass
        else:
            print(x)
# Out:
# £
# ¤
# ©
# «
# ²
# ³
# µ
# ¹
# º
# ¼
# ß
# æ
# ø
# đ
# ŋ
# ɔ
# ʰ
# ˈ
# ˍ
# ː
# ˙
# ˚
# ˢ
# η
# κ
# ς
# υ
# χ
# ψ
# ж
# ф
# х
# ц
# ш
# і
# ب
# ة
# ت
# د
# ر
# س
# ع
# ل
# م
# ن
# ه
# و
# ي
# ۩
# ม
# ย
# ་
# ღ
# ᄀ
# ᄁ
# ᄂ
# ᄃ
# ᄅ
# ᄆ
# ᄈ
# ᄉ
# ᄋ
# ᄌ
# ᄎ
# ᄏ
# ᄐ
# ᄑ
# ᄒ
# ᅡ
# ᅢ
# ᅣ
# ᅥ
# ᅦ
# ᅧ
# ᅨ
# ᅩ
# ᅪ
# ᅬ
# ᅭ
# ᅮ
# ᅯ
# ᅲ
# ᅳ
# ᅴ
# ᅵ
# ᆨ
# ᆫ
# ᆯ
# ᆷ
# ᆸ
# ᆺ
# ᆻ
# ᆼ
# ᗜ
# ᵃ
# ᵉ
# ᵍ
# ᵏ
# ᵐ
# ᵒ
# ᵘ
# ‖
# „
# †
# ‥
#
# ″
# ‹
# ›
# ⁱ
# ⁺
# ⁿ
# ₁
# ₂
# ₃
# ₄
# €
# ℃
# №
# ™
# ⅰ
# ⅱ
# ⅲ
# ⅳ
# ⅴ
# ↔
# ⇒
# ∙
# ∟
# ∣
# ∥
# ∮
# ∼
# ∽
# ≒
# ≪
# ≫
# ⋅
# ⋈
# ①
# ②
# ③
# ④
# ⑤
# ⑥
# ⑦
# ⑧
# ⑨
# ⑩
# ⑴
# ⑵
# ⑶
# ⑷
# ⑸
# ⒈
# ⒉
# ⒊
# ⒋
# ⓒ
# ⓔ
# ⓘ
# ┅
# ┆
# ┊
# ┌
# └
# ├
# ┣
# ═
# ║
# ╚
# ╞
# ╠
# ╱
# ╳
# ▅
# ▇
# ▉
# ▋
# ▌
# ▍
# ▎
# ▫
# ▬
# ▶
# ►
# ◠
# ◢
# ◤
# ☀
# ☕
# ♠
# ♣
# ♦
# ♫
# ♬
# ✈
# ✔
# ✕
# ✖
# ✦
# ✨
# ✪
# ✰
# ❀
# ➜
# ➤
# ⦿
# 〓
# 〝
# 〞
# ぁ
# ぃ
# ぇ
# ぬ
# ゜
# ゥ
# ヌ
# ヨ
# ヲ
# ヶ
# ㄋ
# ㄎ
# ㆍ
# ㈦
# ㊣
# ㎡
# 㗎
# 丟
# 両
# 丼
# 丿
# 乂
# 乗
# 乜
# 乩
# 亀
# 亂
# 亙
# 亜
# 仃
# 仏
# 仝
# 仟
# 仮
# 伉
# 伕
# 伢
# 佇
# 佈
# ...

# %%
"丟" == "丢"
# Out:
# False
